# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
#from sklearn.preprocessing import PCA

# %%
dataset = pd.read_csv('../input/240000-household-electricity-consumption-records/household_power_consumption.csv')
dataset
# Out:
#          index       Date      Time Global_active_power Global_reactive_power  \
# 0            0     1/1/07   0:00:00                2.58                 0.136
# 1            1     1/1/07   0:01:00               2.552                   0.1
# 2            2     1/1/07   0:02:00                2.55                   0.1
# 3            3     1/1/07   0:03:00                2.55                   0.1
# 4            4     1/1/07   0:04:00               2.554                   0.1
# ...        ...        ...       ...                 ...                   ...
# 260635  260635  30/6/2007  23:55:00                2.88                  0.36
# 260636  260636  30/6/2007  23:56:00               2.892                 0.358
# 260637  260637  30/6/2007  23:57:00               2.882                  0.28
# 260638  260638  30/6/2007  23:58:00                2.66                  0.29
# 260639  260639  30/6/2007  23:59:00               2.548                 0.354
#
# ...

# %%
dataset = dataset.drop('index', axis = 1)
dataset = dataset.drop('Sub_metering_1', axis = 1)
dataset = dataset.drop('Sub_metering_2', axis = 1)
dataset = dataset.drop('Sub_metering_3', axis = 1)
dataset.fillna(method = 'ffill', inplace = True)
print(dataset.head())
# Out:
#      Date     Time Global_active_power Global_reactive_power Voltage  \
# 0  1/1/07  0:00:00                2.58                 0.136  241.97
# 1  1/1/07  0:01:00               2.552                   0.1  241.75
# 2  1/1/07  0:02:00                2.55                   0.1  241.64
# 3  1/1/07  0:03:00                2.55                   0.1  241.71
# 4  1/1/07  0:04:00               2.554                   0.1  241.98
#
#   Global_intensity
# 0             10.6
# 1             10.4
# 2             10.4
# 3             10.4
# 4             10.4

# %%
print(dataset.columns)
print("number of rows:", len(dataset))
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity'],
#       dtype='object')
# number of rows: 260640

# %%
scaler = StandardScaler()

dataset_s = scaler.fit_transform(dataset)
dataset_norm = pd.DataFrame(normalize(datset_s))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27/3510764842.py in <module>
#       1 scaler = StandardScaler()
#       2
# ----> 3 dataset_s = scaler.fit_transform(dataset)
#       4 dataset_norm = pd.DataFrame(normalize(datset_s))
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
# ...
