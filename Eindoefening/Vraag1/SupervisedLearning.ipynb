# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn.model_selection import train_test_split
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')

# %%
dataset = pd.read_csv('../input/240000-household-electricity-consumption-records/household_power_consumption.csv')
dataset
# Out:
#          index       Date      Time Global_active_power Global_reactive_power  \
# 0            0     1/1/07   0:00:00                2.58                 0.136
# 1            1     1/1/07   0:01:00               2.552                   0.1
# 2            2     1/1/07   0:02:00                2.55                   0.1
# 3            3     1/1/07   0:03:00                2.55                   0.1
# 4            4     1/1/07   0:04:00               2.554                   0.1
# ...        ...        ...       ...                 ...                   ...
# 260635  260635  30/6/2007  23:55:00                2.88                  0.36
# 260636  260636  30/6/2007  23:56:00               2.892                 0.358
# 260637  260637  30/6/2007  23:57:00               2.882                  0.28
# 260638  260638  30/6/2007  23:58:00                2.66                  0.29
# 260639  260639  30/6/2007  23:59:00               2.548                 0.354
#
#        Voltage Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0       241.97             10.6              0              0             0.0
# 1       241.75             10.4              0              0             0.0
# 2       241.64             10.4              0              0             0.0
# 3       241.71             10.4              0              0             0.0
# 4       241.98             10.4              0              0             0.0
# ...        ...              ...            ...            ...             ...
# 260635  239.01               12              0              0            18.0
# 260636  238.86             12.2              0              0            17.0
# 260637  239.05               12              0              0            18.0
# 260638  238.98             11.2              0              0            18.0
# 260639  239.25             10.6              0              1            17.0
#
# [260640 rows x 10 columns]

# %%
#X = dataset.drop('index',axis=1)
#y = dataset['index']

X = dataset.iloc[:,0] 
y = dataset.iloc[:]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
xg_cl = xgb.XGBClassifier(objective='binary:logistic', n_estimators=10)

# %%
xg_cl.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2665834831.py in <module>
# ----> 1 xg_cl.fit(X_train, y_train)
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     573         for k, arg in zip(sig.parameters, args):
#     574             kwargs[k] = arg
# --> 575         return f(**kwargs)
#     576
#     577     return inner_f
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1348             expected_classes = cp.arange(self.n_classes_)
#    1349         else:
# -> 1350             self.classes_ = np.unique(np.asarray(y))
#    1351             self.n_classes_ = len(self.classes_)
#    1352             expected_classes = np.arange(self.n_classes_)
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     331         aux = ar[perm]
#     332     else:
# --> 333         ar.sort()
#     334         aux = ar
#     335     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
preds = xg_cl.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_27/2928478284.py in <module>
# ----> 1 preds = xg_cl.predict(X_test)
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1438             validate_features=validate_features,
#    1439             base_margin=base_margin,
# -> 1440             iteration_range=iteration_range,
#    1441         )
#    1442         if output_margin:
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1042         """
#    1043         iteration_range = _convert_ntree_limit(
# -> 1044             self.get_booster(), ntree_limit, iteration_range
#    1045         )
#    1046         iteration_range = self._get_iteration_range(iteration_range)
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in get_booster(self)
#     588         if not self.__sklearn_is_fitted__():
#     589             from sklearn.exceptions import NotFittedError
# --> 590             raise NotFittedError('need to call fit or load_model beforehand')
#     591         return self._Booster
#     592
#
# NotFittedError: need to call fit or load_model beforehand
